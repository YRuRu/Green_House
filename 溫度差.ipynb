# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("CFD_temp.csv")

# %%
data.head()
# Out:
#          TIMESTAMP  Temp_C_Avg(1)  Temp_C_Avg(2)  Temp_C_Avg(3)  \
# 0  2019/1/31 14:50          31.19          31.42          31.58
# 1  2019/1/31 15:00          29.95          30.08          30.29
# 2  2019/1/31 15:10          29.54          29.87          29.91
# 3  2019/1/31 15:20          28.98          29.64          29.24
# 4  2019/1/31 15:30          28.41          28.92          28.99
#
#    Temp_C_Avg(4)  Temp_C_Avg(5)  Temp_C_Avg(6)  Temp_C_Avg(7)  Temp_C_Avg(8)  \
# 0          31.30          31.10          32.03          32.09          32.46
# 1          30.03          30.01          30.45          30.29          30.61
# 2          29.81          29.41          30.10          29.85          30.32
# 3          29.12          29.00          29.88          29.32          29.90
# 4          28.67          28.60          28.93          28.64          29.11
#
#    Temp_C_Avg(9)  Temp_C_Avg(10)
# 0          32.19           31.59
# 1          30.53           30.01
# ...

# %%
datalist=data.columns[1:]

# %%
diff=[]
for j in range(len(data["Temp_C_Avg(4)"])):
    diff.append(data["Temp_C_Avg(4)"][j+1]-data["Temp_C_Avg(4)"][j])
    #print(j)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-cbc66aa645af> in <module>
#       1 diff=[]
#       2 for j in range(len(data["Temp_C_Avg(4)"])):
# ----> 3     diff.append(data["Temp_C_Avg(4)"][j+1]-data["Temp_C_Avg(4)"][j])
#       4     #print(j)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4372         try:
#    4373             return self._engine.get_value(s, k,
# -> 4374                                           tz=getattr(series.dtype, 'tz', None))
#    4375         except KeyError as e1:
# ...

# %%
absdiff=[]
for i in diff:
    absdiff.append(abs(i))

# %%
max(absdiff)
# Out:
# 2.0100000000000016

# %%
for i in datalist:
    for j in data[i]:
        print(i)
        for k in j:
            diff=[]
        
        print("\n")
# Out:
# 31.19
# 29.95
# 29.54
# 28.98
# 28.41
# 28.06
# 27.95
# 27.72
# 27.73
# 27.67
# 27.48
# 27.03
# 26.48
# 25.96
# 25.54
# 25.11
# 24.65
# 24.28
# 23.9
# 23.52
# 23.03
# 22.81
# 22.44
# 22.29
# 22.0
# 21.66
# 22.35
# 22.07
# 21.88
# 21.65
# 21.16
# 21.11
# 20.7
# 19.89
# 19.21
# 18.96
# 18.91
# 18.47
# 18.53
# 18.51
# 18.07
# 17.93
# 17.89
# 17.98
# 17.71
# 17.67
# 17.34
# 17.34
# 17.21
# 17.03
# 16.79
# 16.48
# 16.49
# 16.07
# 15.78
# 15.67
# 15.89
# 15.79
# 15.72
# 15.85
# 16.14
# 15.86
# 15.52
# 15.5
# 15.27
# 15.15
# 14.93
# 15.01
# 15.28
# 15.46
# 15.42
# 15.33
# 15.29
# 15.23
# 15.17
# 15.09
# 14.98
# 14.84
# 14.71
# 14.64
# 14.47
# 14.52
# 14.65
# 14.75
# 14.78
# 14.86
# 14.84
# 14.78
# 14.78
# 14.75
# 14.83
# 14.76
# 14.77
# 14.8
# 14.92
# 14.94
# 14.97
# 15.14
# 15.22
# 15.36
# 15.53
# 15.64
# 15.79
# 16.03
# 16.87
# 17.5
# 17.29
# 17.03
# 17.33
# 17.21
# 17.23
# 17.68
# 18.04
# 19.21
# 18.79
# 18.55
# 18.23
# 18.93
# 19.57
# 18.95
# 18.65
# 19.43
# 19.62
# 19.68
# 20.29
# ...
